# %%
import pandas as pd

# %%
df1 = pd.read_csv("Airline_delay_cause.csv")
df2 = pd.read_csv("Cleaned_2018_Flights.csv")

# %%
df1 = df1.dropna()
df1 = df1.reset_index(drop=True)
df1 = df1.drop_duplicates()
df1.isna().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
df2 = df2.dropna()
df2 = df2.reset_index(drop=True)
df2 = df2.drop_duplicates()
df2.isna().sum()
# Out:
# Unnamed: 0           0
# ItinID               0
# MktID                0
# MktCoupons           0
# Quarter              0
# Origin               0
# OriginWac            0
# Dest                 0
# DestWac              0
# Miles                0
# ContiguousUSA        0
# NumTicketsOrdered    0
# AirlineCompany       0
# PricePerTicket       0
# dtype: int64

# %%
df1
# Out:
#         year  month carrier            carrier_name airport  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE
# 1       2023      8      9E       Endeavor Air Inc.     ABY
# 2       2023      8      9E       Endeavor Air Inc.     AEX
# 3       2023      8      9E       Endeavor Air Inc.     AGS
# 4       2023      8      9E       Endeavor Air Inc.     ALB
# ...      ...    ...     ...                     ...     ...
# 171218  2013      8      YV      Mesa Airlines Inc.     TRI
# 171219  2013      8      YV      Mesa Airlines Inc.     YUM
# 171220  2013      8      YV      Mesa Airlines Inc.     SLC
# 171221  2013      8      DL    Delta Air Lines Inc.     SBN
# 171222  2013      8      F9  Frontier Airlines Inc.     MTJ
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0
# 1                  Albany, GA: Southwest Georgia Regional         62.0
# ...

# %%
df1 = df1.drop(columns=["carrier","airport_name","FLIGHT_NUM","ORIGIN_SEQ_ID","DEST_SEQ_ID","DEP_TIME","ARR_TIME","WEATHER_DELAY"])
df1

# %%
df2 = df2.drop(columns=["ItinID","MktID","MktCoupons","ContiguousUSA","NumTicketsOrdered","AirlineCompany"])
df2

# %% [markdown]
# **Passar data para quarter de forma a alinhar com dataset2**

# %%
df1_2018 = df1[df1["FL_DATE"].str.endswith("/18")]
print(df1_2018)

# %%
df1_2018 = df1[df1["FL_DATE"].str.endswith("/18")]
meses_unicos = df1_2018["FL_DATE"].str.slice(0, 2).unique()
numero_meses_unicos = len(meses_unicos)
print(numero_meses_unicos)

# %% [markdown]
# Este dataset apenas tem registos do mes 8 em 2018

# %%
df1 = df1[df1["FL_DATE"].str.endswith("/18")]
df1

# %% [markdown]
# Filtrar apenas quarter 4
